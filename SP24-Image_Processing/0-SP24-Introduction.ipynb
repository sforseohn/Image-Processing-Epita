# %% [markdown]
# # <font color="dodgerblue">Image processing: Toward a Baby-football Image Assistant Referee</font>

# %% [markdown]
# Welcome to this course! <font size='5'>😀</font>
#
# We hope you enjoy your summer school! <font size='5'>🌤🏫</font>
#
# This course is an introduction to image and video processing notions applied to a concrete example of application which consists of <font size='2'>🎯</font> detecting and <font size='2'>👣</font> tracking a  <font size='2'>&#x26BD;</font> ball from a <font size='2'>🏟</font> baby-football video in order to count the goal scores automatically.

# %% [markdown]
# ## <font color="dodgerblue">Time volume</font>
#
# - Total hours worked: 18
# - Face-to-face Volume: 18
#
# ## <font color="dodgerblue">Requirements</font>
#
# - Matrix concepts
# - <font size='2'>🐍</font> Python programming
#
# ## <font color="dodgerblue">Keywords</font>
#
# - Image processing
# - Computer vision
# - Object Detection / Tracking
#
# ## <font color="dodgerblue">Context</font>
#
# We assume that the baby-football is considered as part as the 2024's olympic games. <font size='2'>⚽ 🏓 🏀 🥋 🏈 🏋</font>
#
# In order to help <font size='2'></font> refereeing the baby-football matches, an image processing and a computer vision process could be useful to detect and track the ball and help, for example, to count the goals.
#
# - Baby-football
# - Olympic games 2024
#
# ## <font color="dodgerblue">Background</font>
#
# Images are nowadays easy to acquire. Almost everyone has now a <font size='2'>📸</font> camera embedded into their <font size='2'>📱</font> phone.
#
# An <font size='2'>🏙</font> image can be considered as a data source. It may contain <font size='2'>💰</font> valuable information that can be relevant for our daily lives.
# Such content could be processed and analyzed to bring many improvements on different fields of application where <font color='maroon'>object detection</font>, <font color='maroon'>object recognition</font> and <font color='maroon'>object tracking</font> can be <font size='2'>🥊</font> challenging. <font size='2'>💉</font> Medical image processing and analysis could, for instance, help the doctor to rapidly detect a concerous lesion and save his <font size='2'>😷</font> patient. <font size='2'>🌍</font> Geographs could also be helped by reducing their <font size='2'>🗺</font> map hand drawing task which is greatly <font size='2'>⌚</font> time-consuming. Many works on <font size='2'>🛰</font> remote sensing image processing have been proposed in order to bring a potential map <font size='2'>🗺</font> generation result.
# And Last, but not least, autonomous <font size='2'>🚗</font> cars could now drive by themselves thanks to advances in computer vision.
# Autonomous <font size='2'>🚌</font> vehicles or <font size='2'>🤖</font> robots could now be made to recognize a safe <font size='2'>🛣</font> road, avoid <font size='2'>🚧</font> obstacles and go to the <font size='2'>🎯</font> target location.
#
# ## <font color="dodgerblue">Learning outcomes</font>
#
# At the end of this course, students should:
#
# - Have a basic understanding of image processing and comuter vision;
# - Be familiar with Jupyter Notebook or Jupyter Lab for image processing;
# - Be familiar to a python library as scikit-image;
# - Understand the different steps:
#     - Preprocessing
#     - Segmentation
#     - Detection
#     - Tracking
#     - Optimization
#
# ## <font color="dodgerblue">Activity format</font>
#
# The course consists of :
#
# - 18 hours of guided lab sessions
#
#   - <font size='2'>🔬</font> **Session-1 (3h):**
#     - Introduction
#     - Nixos and Jupyter environment
#     - Image and Video processing
#
#   - <font size='2'>🔬</font> **Session-2 (3h):**
#     - Image histogram
#     - Image profiling
#     - Manual image and video binarization / segmentation
#
#   - <font size='2'>🔬</font> **Session-3 (3h):**
#     - Image and video filtering
#     - Automated image and video binarization / segmentation
#
#   - <font size='2'>🔬</font> **Session-4 (3h):**
#     - Mathematical morphology
#     - Ball detection
#
#   - <font size='2'>🔬</font> **Session-5 (3h):**
#     - Ball tracking
#     - Optimization
#     - Robustness
#
#   - <font size='2'>🔬</font> **Session-6 (3h):**
#     - Goal cage detection
#     - Goal count
#
# ## <font color="dodgerblue">MCQ Evaluation</font>
#
# - Understanding and validating the concepts of:
#   - Image and video processing
#   - Preprocessing (filtering, histogram, profiling)
#   - Mathematical morphology
#
# ## <font color="dodgerblue">Final score calculation</font>
#
# - **MCQ-1 score:** 5 pts
# - **MCQ-2 score:** 5 pts
# - **MCQ-3 score:** 5 pts
# - **MCQ-4 score:** 5 pts
# - **Final score:** 20 pts
# - **Minimal score for validation** 10 pts
#
# ## <font color="dodgerblue">References</font>
#
# - [jupyter](https://jupyter.org/)
# - [ipython](https://ipython.org/)
# - [scikit-image](https://scikit-image.org/)
#
# ## <font color="dodgerblue">For what result?</font>
#
# <img src='videos/result_video.webp'/>
